# %%
# !pip install fix_yahoo_finance
# Out:
# Collecting fix_yahoo_finance
#   Using cached fix-yahoo-finance-0.1.37.tar.gz (6.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [8 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\Barath Murugan\AppData\Local\Temp\pip-install-_wbzxauq\fix-yahoo-finance_ce9cbc8ca8804ad884a875db3ee54c58\setup.py", line 19, in <module>
#       from fix_yahoo_finance import __version__
#     File "C:\Users\Barath Murugan\AppData\Local\Temp\pip-install-_wbzxauq\fix-yahoo-finance_ce9cbc8ca8804ad884a875db3ee54c58\fix_yahoo_finance\__init__.py", line 22, in <module>
#       import yfinance
#   ModuleNotFoundError: No module named 'yfinance'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.17-py2.py3-none-any.whl (60 kB)
#      ---------------------------------------- 60.3/60.3 kB 1.6 MB/s eta 0:00:00
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      -------------------------------------- 112.2/112.2 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\barath murugan\anaconda3\lib\site-packages (from yfinance) (37.0.1)
# Requirement already satisfied: requests>=2.26 in c:\users\barath murugan\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\barath murugan\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.7-cp39-cp39-win_amd64.whl (35 kB)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\barath murugan\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\barath murugan\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Collecting pytz>=2022.5
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      -------------------------------------- 502.3/502.3 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3.0 in c:\users\barath murugan\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\barath murugan\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\barath murugan\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\barath murugan\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in c:\users\barath murugan\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\barath murugan\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\barath murugan\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\barath murugan\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\barath murugan\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\barath murugan\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\barath murugan\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: pycparser in c:\users\barath murugan\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Installing collected packages: pytz, multitasking, html5lib, frozendict, yfinance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.1
#     Uninstalling pytz-2022.1:
#       Successfully uninstalled pytz-2022.1
# Successfully installed frozendict-2.3.7 html5lib-1.1 multitasking-0.0.11 pytz-2023.3 yfinance-0.2.17
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\barath murugan\anaconda3\lib\site-packages)

# %%
import yfinance as yfin
yfin.pdr_override()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from pandas_datareader import data as pdr

# import data
def get_data(stocks, start, end):
    stockData = pdr.get_data_yahoo(stocks, start, end)
    stockData = stockData['Close']
    returns = stockData.pct_change()
    meanReturns = returns.mean()
    covMatrix = returns.cov()
    return meanReturns, covMatrix

stockList = ['CBA', 'BHP', 'TLS', 'NAB', 'WBC', 'STO']
stocks = [stock + '.AX' for stock in stockList]
endDate = dt.datetime.now()
startDate = endDate - dt.timedelta(days=300)

meanReturns, covMatrix = get_data(stocks, startDate, endDate)

weights = np.random.random(len(meanReturns))
weights /= np.sum(weights)
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
# Monte Carlo Method
mc_sims = 20 # number of simulations
T = 100 #timeframe in days

meanM = np.full(shape=(T, len(weights)), fill_value=meanReturns)
meanM = meanM.T

portfolio_sims = np.full(shape=(T, mc_sims), fill_value=0.0)

initialPortfolio = 10000

for m in range(0, mc_sims):
    Z = np.random.normal(size=(T, len(weights)))#uncorrelated RV's
    L = np.linalg.cholesky(covMatrix) #Cholesky decomposition to Lower Triangular Matrix
    dailyReturns = meanM + np.inner(L, Z) #Correlated daily returns for individual stocks
    portfolio_sims[:,m] = np.cumprod(np.inner(weights, dailyReturns.T)+1)*initialPortfolio

plt.plot(portfolio_sims)
plt.ylabel('Portfolio Value ($)')
plt.xlabel('Days')
plt.title('MC simulation of a stock portfolio')
plt.show()

# %% [markdown]
# https://youtube.com/watch?v=6-dhdMDiYWQ&feature=share&si=EMSIkaIECMiOmarE6JChQQ
